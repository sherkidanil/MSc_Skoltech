# %% [markdown]
# # Problem Set 1 (61 points)

# %% [markdown]
# ## Important information
# 1.  We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2.  Please submit the single Jupyter Notebook file, where only Python and Markdown/$\\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!
# 3.  The works will be checked for **plagiarism**. The score will be divided by the number of similar works.

# %% [markdown]
# # Problem 1 (18 pts)

# %% [markdown]
# ### Problem 1.0 (Matrix norms) (8 pts)
#
# 1. For any norm $\|\cdot\|$ in finite dimentional space $\mathbb{C}^{N}$ we define dual norm $\|x\|^{'} = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\}$, where ${\cdot}^{\star}$ denotes transpose complex-conjugate vector.
#
# + (2 pts). Prove that $\|\cdot\|^{'}$ is a norm.
#
# + (2 pts). Find dual norms for Chebyshev norm $\left\|x\right\|_{\infty} = \max\limits_{i=1,\dots, N}|x_{i}|$ and $l_1$ norm $\left\|x\right\|_1 = \sum\limits_{i=1}^{N}|x_{i}|$.
#
# + (2 pts). Find dual norm for $l_p$ norm $\left\|x\right\|_{p} = \left(\sum\limits_{i=1}^{N}|x_{i}|^{p}\right)^{1/p}$.
#
# + (2 pts). Find dual norm for weighted norm $\left\|x\right\|_{A} = \left(x^T A x\right)^{1/2}$ with positive-definite matrix $A$ and $x\in\mathbb{R}^{N}$.

# %% [markdown]
# --------
# ### Task 1.0.1
#
# Acording to lecture 1 material, we know that $\Vert \cdot \Vert$ is called a  **vector norm** if it is satisfy certain properties:
#
# 1. $\Vert \alpha x \Vert = |\alpha| \Vert x \Vert$
# 2. $\Vert x + y \Vert \leq \Vert x \Vert + \Vert y \Vert$ (triangle inequality)
# 3. If $\Vert x \Vert = 0$ then $x = 0$
#
# Let's check this properties for  $\|\cdot\|^{'}$ to prove that it is norm
#
# 1. It's easy to check because  $\|\alpha x\|^{'} = \sup\left\{\left|y^{\star} \alpha x\right|:\left\|y\right\|=1\right\} = |\alpha| \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} = |\alpha| \| x\|^{'}$
# 2. smthg
#
# $$\|x+z\|^{'} = \sup\left\{\left|y^{\star} (x+z)\right|:\left\|y\right\|=1\right\}$$
#
# $$\Vert x+z \Vert ^{'} = \Vert y^{\star} (x+z) \Vert ^{'} = \Vert y^{\star} x+y^{\star} z \Vert ^{'} $$
#
# $$\Vert x+z \Vert ^{'}\leq \Vert y^{\star} x \Vert ^{'} + \Vert y^{\star} z \Vert ^{'}$$
#
# $$\Vert x+z \Vert ^{'} \leq (\Vert x \Vert ^{'} + \Vert z \Vert ^{'}) \Vert y^{\star}\Vert ^{'}$$
#
# $$\Vert x+z \Vert ^{'} \leq \Vert x \Vert ^{'} + \Vert z \Vert ^{'}$$
#
# 3. It's easy to check too, because if $\| x\|^{'} = 0$ then $\sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} = 0$ and it's means that multiplication product $\left|y^{\star} x\right|$ must be equal to zero. That is, one of the multipliers must be zero. For $y^{\star} = 0$, it's neccessary that $y=0$, but according to third property of the norm, we now that when $x = 0$,  $\Vert x \Vert = 0$. Thus, only $x$ can be equal to zero and $\| x\|^{'} = 0$ means that $x = 0$

# %% [markdown]
# ---
# ### Task 1.0.2
#
# Find dual norms for Chebyshev norm $\left\|x\right\|_{\infty} = \max\limits_{i=1,\dots, N}|x_{i}|$ and $l_1$ norm $\left\|x\right\|_1 = \sum\limits_{i=1}^{N}|x_{i}|$.
#
# ---
#
# We can rewrite $|y^{\star}x|$ as $|x^{\star} y |$
#
# It's means that
#
# $$\Vert x \Vert^{'}_{\infty} = \sup\left\{\left|x^{\star} y\right|:\left\|y\right\| _ {\infty}=1\right\} $$
#
# According to Holder inequality property, we can say that
#
# $$|x^{\star} y| \leq \Vert x \Vert_{1} \Vert y \Vert_{\infty} \leq \Vert x \Vert_{1} $$
#
# Thus, we conclude that $|x^{\star}y| \leq \Vert x \Vert_{1}$
#
# It's mean that the maximum our function equal
#
# **need to change**
# $$\Vert y \Vert_{\infty} =\max_i{|y_i|} = 1$$
#
# $$\max_i{|y_i|} = 1$$
#
# $$ \Vert x \Vert^{'}_{\infty} = \sup\left\{\left|x^{\star} y\right|:\left\|y\right\| _ {\infty}=1\right\}$$
#
# **utochnit**
# $$\begin{aligned}
# | x^{\star} y | &= \sum_{i}^{N} x_i y_i \leq \sum_{i}^{N} | x_i y_i | \\
# &\leq \sum_{i=1}^{N} |x_i||y_i| \\
# &\leq \sum_{i=1}^{N} |x_i| \\
# &= \Vert x \Vert_1
# \end{aligned}$$

# %% [markdown]
# ---
# $$\|x\|_1^{'} = \sup\left\{\left|y^{\star} x\right|:\left\|y \right\|_1 =1\right\}$$
#
# L1-norm by defifinition
#
# $$\Vert x \Vert_1 = \sum_{i=1}^{N} |x_i| $$
#
# And we know
#
# $$\Vert y \Vert_1 = 1 $$
#
# It's mean that
#
# $$\Vert y \Vert_1 = \sum_{i=1}^{N} |y_i|$$
#
# $$
# \begin{aligned}
# |x^{\star} y| &=  \sum_{i=1}^{N} |x_i y_i| \leq \sum_{i=1}^{N} |x_i| |y_i|  \\
# &\leq \sum_{i=1}^{N} |x_i| |y_i| \\
# & \leq \frac{(\sum_{i=1}^{N} |x_i y_i|)(\sum_{i=1}^{N} |y_i|)}{\sum_{i=1}^{N} |y_i|} \\
# & \leq \max_i |x| \sum_{i=1}^{N} |x_i y_i|
# \end{aligned}
# $$
#
# $$\Vert x \Vert_{1}^{'} \leq \max{|x_i|}, \Vert y \Vert_{1} = 1$$
#
# $$y = \frac{x}{\Vert x \Vert_{\infty}}$$
#
# $$\Vert x \Vert_{1}^{'} = \max{|x_i|}, \Vert y \Vert_{1} = 1$$
#
# $$\Vert x \Vert_{1}^{'}  = \Vert x \Vert_{\infty}$$

# %% [markdown]
# ---
# ### Task 1.0.3
#
# Find dual norm for $l_p$ norm $\left\|x\right\|_{p} = \left(\sum\limits_{i=1}^{N}|x_{i}|^{p}\right)^{1/p}$.
#
# $$\Vert x \Vert^{'} = \sup{x^{\star}, \Vert y \Vert_p = 1}$$
#
# $$
# \begin{aligned}
# x^{\star} y =\sum_{i=1}^{N}x_i y_i =\sum_{i=1}^{N} | x_i y_i| = \Vert x y \Vert _1 \leq \Vert x \Vert_p \Vert y\Vert_p
# \end{aligned}
# $$
# $$x^{\star} y  \leq  \Vert x \Vert_p $$
#
# We need remeber Holder pairs and Holder inequality

# %% [markdown]
# ---
# ### Task 1.0.4
#
# Set the $z = A^{1/2}$
# $y = A^{-1/2}z$
#
# $$\Vert x \Vert_{A}^{'} = sup{|x^* A^{-0.5}|z} = sup{|x^* A^{-0.5}x z|}$$
#
# and more.. but I have no time( sorry

# %% [markdown]
# ### Problem 1.1 (Matrix norms) (10 pts)
#
# 1. Let $U \in \mathbb{R}^{n \times r}$ be an $n \times r$ matrix with orthonormal columns $U^{\top} U = I_r$. Let $V$ be an $m \times r$ matrix.
#
# + (2 pts). Propose an algorithm for the computation of $\Vert A \Vert^2_F$, where $A = U V^{\top}$, and estimate its complexity with respect to $n, m, r$. How orthogonalization can be used?
#
# + (3 pts). Consider the matrix $B = A \circ A$, where $\circ$ is the elementwise product of matrices (i.e., the elements of the matrix $B$ are squares of the elements of the matrix $A$). What is the maximal possible rank of the matrix $B$?
#
# + (5 pts). Propose an algorithm for the computation of $\Vert B \Vert^2_F$ and estimate its complexity with respect to $n, m, r$.

# %% [markdown]
# ---
# ### Task 1.1.1
# For Frobenious norm we know that
# $$\Vert A \Vert_{F}^2 = \sum_{i=1}^{n}\sum_{j=1}^{m}|a_{ij}|^2$$
# $$\Vert A \Vert_{F}^2 = trace(AA^{T})$$
#
# And we can rewrite $A = UV^{T}$ that
# $$A = \sum_{k=1}^{r}u_{ik}v_{kj}$$
# $$\Vert A \Vert_{F}^2 = \sum_{i=1}^{n}\sum_{j=1}^{m}|\sum_{k=1}^{r}u_{ik}v_{kj}|^2$$
#
# And if we apply the property above
# $$\Vert A \Vert_{F}^2 = trace(VU^T UV^T)$$
# $$\Vert A \Vert_{F}^2 = trace(VI_rV^T)$$
# $$\Vert A \Vert_{F}^2 = trace(VV^T) = trace(I_m)$$
#
# U - unitary and it's mean that mulrtyplying by that matrix Frobenius norm isn't change
# $$\Vert A \Vert_{F}^2 = \Vert UV^T \Vert_{F}^2 =\Vert V^T \Vert_{F}^2 $$
# $$\Vert A \Vert_{F}^2 =\sum_{i=1}^{n}\sum_{j=1}^{m}|v_{ij}|^2 = trace(VV^T)$$
#  Thus,if $m>r$ then
#
#  $$\Vert A \Vert_{F}^2  = \sum_{i=1}^{r} \sigma(VV^T)$$
#
#  And if $r>m$ then
#
#  $$\Vert A \Vert_{F}^2  = \sum_{i=1}^{m} \sigma(V^TV)$$
#
# The algorithm complexity depends on m,r
#
# ---
# ### Task 1.1.2
#
# By definition
# $$B = A \circ A = UV^T \circ UV^T = \sum_{i=1}^{r} u_i v_i \circ \sum_{i=1}^{r} u_i v_i = \sum_{i,j=1}^{r} (u_i v_i) \circ (u_j v_j) =\sum_{i,j=1}^{r} (u_i u_j)  (v_i v_j) $$
#
# ---
# ### Task 1.1.3
#
# $$B = trace(B^T B) $$
#
# $$\Vert B \Vert_{F}^2 = \sum_{i=1}^{n}\sum_{j=1}^{m}|b_{ij}|^2 = \sum_{i=1}^{n}\sum_{j=1}^{m}|a^2_{ij}|^2 = \sum_{i=1}^{n}\sum_{j=1}^{m}a^4_{ij} =\sum_{i=1}^{n}\sum_{j=1}^{m}\sum_{k=1}^{r}u_{ik}v_{kj} $$
#
# I can assume that algorithm complexity expected $𝒪(r^3 \cdot (m+n))$

# %% [markdown]
# ### Problem 1.2 (Unitary and orthogonal matrices) (4 pts)
#
# + (2 pts). Let $O\in\mathbb{R}^{n\times n}$ be orthogonal matrix. Characterise explicitly all orthogonal matrices that are positive definite. You may start with $n=2$.
#
# + (2 pts). Show that any unitary matrix from $\mathbb{C}^{n\times n}$ can be represented as a product of at most $n$ Householder reflectors.

# %% [markdown]
# ---
# ### Task 1.2.1
#
# Acoording to lecture and handbooks, we can say that $O$ **pd** and othogonal if
# 1. $x^TOx > 0$
# 2. $OO^T = O^T O$
#
# According to eigenvalues theory
# $$Ox = \lambda x$$
# $$x^TOx  =x^T \lambda x > 0$$
#
# For orthogonal matrix, inverse matrix equal transpose matrix, and it's means that
#
# $$OO^T = O^T O = I$$
#
# and $\det(O) = \pm 1$
#
# Thus, $O$ positive deifinite and orthogonal when eigenvalues > 0
#
# ---
# ### Task 1.2.2
# $$HH^{\star} = (I-2vv^{\star})(I-2vv^{\star})^{\star}$$
# $$HH^{\star} = (I-2vv^{\star})(I-2v^{\star}v) = I-4vv^{\star}+4vv^{\star} = I$$
#
# And we see that product n Householder reflectors would be $I$.
#
# And any unitary matrix we acn represent as
# $H_1..H_k D^{n\times n}$, where $D$ is diagonal matrix
# $$D = diag(e^{i \theta_1},.., e^{i \theta n})$$
#
# For any $\theta$ would be different unitary matrix.

# %% [markdown]
# # Problem 2 (15 pts)
#
# 1. We define approximate $\epsilon-$rank of matrix $A$ as $\text{rank}_{\epsilon}A = \min \left\{\text{rank}(X): \left\|A-X\right\|_{\max}\leq \epsilon\right\}$.
#
#
# + (6 pts). Let $f(x, y),\,x,y\in[0, 1]$ is analytic function with $\left.\partial_y^{(k)}f(x, y)\right|_{y=0}\leq M$ for all $k$. Show that approximate rank of matrix $A_{ij} = f(x_i, y_j)$ where $x_{i},\,i=1,\dots,p$, $y_{j},\,j=1,\dots,q$ are arbitrary points inside $[0, 1]^2$, is bounded independent of $p$, $q$ and the choice of points.
#
# + (6 pts). Extend result from the previous point (a.) to $x, y \in \mathbb{R}^{N}$. Observe how the bound depends on $N$.
#
# + (3 pts). Demonstarate your bounds from two previous points numerically on functions
#
#     + (1 pts). $\cos(xy)$, $\exp(-(x-y)^2)$ and a few on your choice for $N=1$
#     + (1 pts). [RBF kernel](https://scikit-learn.org/stable/modules/gaussian_process.html#radial-basis-function-rbf-kernel) for different $N$.
#     + (1 pts). [Exp-Sine-Squared kernel](https://scikit-learn.org/stable/modules/gaussian_process.html#exp-sine-squared-kernel) for different $N$.

# %% [markdown]
# ---
# ### Task 2.1
# If we assume that the function depends only on $y$, we can decompose the function into a Taylor series
#
# $$f(y) = f(0)+ \sum_{k=1}^{N}\frac{f^{k}(y)}{k!}y^{k}$$
#
# but $\left.\partial_y^{(k)}f(x, y)\right|_{y=0}\leq M$ for all $k$
#
# $$f(x,y)\leq f(0) + M \sum_{k=1}^{N}\frac{1}{k!}y^{k}$$
#
# $$f(x,y)- M \sum_{k=1}^{N}\frac{1}{k!}y^{k} = \delta$$
#
# It's means
#
# $$ \Vert A-X\Vert_{\max} \leq \epsilon $$
#
# $$ \max_{ij}| A_{ij} - X_{ij}| \leq \epsilon$$
#
# And N exist > 0 for
# $$ \max_{ij}| \delta_{ij}| \leq \epsilon$$
#
# where $\delta$ depends on N
#
# Obviously, $\epsilon$ can be in range from 1 to n.
#
# $$ f(x_i, y_j) = M \sum^{\infty}_{k=0}\frac{1}{k!}y_j^{k} = \delta_{ij}$$
#
# $$\delta_{ij} \geq Me(1-\frac{\Gamma(n+1, n)}{\Gamma{n}})$$
#
# $$-\epsilon\leq Me(1-\frac{\Gamma(n+1, n)}{\Gamma{n}}) \geq \epsilon$$
#
# $$\varepsilon = \frac{\epsilon}{Me}$$
#
# $$\frac{\Gamma(n+1, n)}{\Gamma{(n)}} \in [1 - \varepsilon;1 + \varepsilon ]$$

# %% [markdown]
# ---
# ### Task 2.2
#
# According the previous task, we can assume that еhe points are in a bounded space, which is a square $[0,1]^2$.  For R^n our solution will turn into a solution from p*q to p*q*N, which can be performed by iterative calculations. And the delta error function will be the elements of the three-dimensional tensor.

# %% [markdown]
# ---
# ### Task 2.3

# %%
#as you can see, our epsilon-rank is not depend on function

import mpmath as mp
p = 100
q = 200
x = np.random.rand(p)
y = np.random.rand(q)
func = np.empty([p, q])

for i in range(len(x)):
  for j in range(len(y)):
    func[i, j] = np.exp((-x[i] - y[j])**2)

N = 100
n_list = []
n = 0
eps = 1e-8
M = 10

for i in range(100):
  if (1 - eps / (M * np.exp(1))<= mp.gammainc(n + 1, 1) / mp.gamma(n + 1) < 1 + eps / (M * np.exp(1))):
    n_list.append(i)
  n += 1
rank = np.array(n_list).min()
rank
# Out:
# 12

# %% [markdown]
# # Problem 3 (Molecules) (16 pts)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# We have in our posession a database with molecules. Each molecule has five atoms `A`, `B`, `C`, `D`, `E` located in the same plane $x, y$.
#
# The coordinates of the molecules was collected by an automatic system that processed "pictures" from the electronic microscope. As a result, some of the samples differs by unkonwn rotation in $2D$ space. Your task is to normalize this database to find distinct molecules.

# %%
data = pd.read_csv("https://raw.githubusercontent.com/oseledets/nla2022/main/hw1/molecules.csv", index_col=0)
data.head()
# Out:
#         A_x  A_y       B_x       B_y       C_x       C_y       D_x       D_y  \
# sample
# 0       0.0  0.0 -0.568099 -0.822960  0.411480 -0.284050 -0.983627 -0.180214
# 1       0.0  0.0 -0.816462  0.577399  0.288700  0.408231 -0.169043  0.985609
# 2       0.0  0.0 -0.999628 -0.027283  0.013642 -0.499814 -0.726136  0.687551
# 3       0.0  0.0  0.946140  0.323758 -0.161879  0.473070 -0.897953  0.440091
# 4       0.0  0.0 -0.901767  0.432222 -0.216111 -0.450884  0.332018 -0.943273
#
#              E_x       E_y
# sample
# 0      -0.180214  0.983627
# 1       0.169043 -0.985609
# 2       0.687551  0.726136
# 3      -0.440091 -0.897953
# 4       0.943273  0.332018

# %%
molecules = data.to_numpy().reshape(len(data), 5, 2)
molecules.shape
# Out:
# (500, 5, 2)

# %%
def draw_molecule(ax, molecule):
    ax.scatter(*molecule.T, color="black", s=50)
    for i in range(1, molecule.shape[0]):
        ax.plot(*molecule[[0, i], :].T, color="black")
    ax.axis("off")
    ax.axis("equal")

# %%
k = 5
fig, ax = plt.subplots(k, k, figsize=(2*k, 2*k))
ax = ax.reshape(-1,)
for i in range(k**2):
    draw_molecule(ax[i], molecules[i])

# %% [markdown]
# ## What you should do:
#
# + (2 pts). Prove that orthogonal transformations preserve $l_2$ norm, i.e., $\left\|x\right\|_2 = \left\|Ux\right\|_2$, where $U$ is an orthogonal matrix.

# %%
#your solution

# I don't have time to write, but I saw the theoretical proof in Tyrtyshnikov
# and can tell you in person!!


import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

alpha = -3*jnp.pi/4
G = jnp.array([
    [jnp.cos(alpha), -jnp.sin(alpha)],
    [jnp.sin(alpha), jnp.cos(alpha)]
])
x = jnp.array([-1./jnp.sqrt(2), 1./jnp.sqrt(2)])
y = G @ x

print('Source matrix norm:', jnp.round(jnp.linalg.norm(x,2),5),
      ', transform matrix norm: ', jnp.round(jnp.linalg.norm(y,2),5))



# for fourier transformation it's same
#NEED TO WRITE FOURIER TRANSFORMATION
# Out:
# Source matrix norm: 1.0 , transform matrix norm:  1.0

# %% [markdown]
# + (4 pts). Use the result from the previous point to construct an algorithm that distinguishes different molecules. Implement it and run on the database. Produce a list of distinct molecules and visualise them.

# %%
# Let's create a vector of l2-norm for each molecule
molecule_norm2 = []
for i in range(molecules.shape[0]):
  molecule_norm2.append(jnp.round(jnp.linalg.norm(molecules[i],2),4))
molecule_norm2 = np.array(molecule_norm2) #done 

# For next operations we should create a vector with unique norms
unique_norms = np.unique(molecule_norm2)

# Then we can create a list with several vectors
# where each vector contains indexes for one unique norm value
diff_molecule_type = []
for i in range(len(unique_norms)):
  molecule_list = []
  for j in range(len(molecule_norm2)):
    if molecule_norm2[j] == unique_norms[i]:
      molecule_list.append(j)
  diff_molecule_type.append(molecule_list)

# Thus, we can produce a diction with unique-norm as keys
# and its corresponding list of molecule indexes as values
divided_molecules = dict(zip(unique_norms, diff_molecule_type))

# I wanted to take a first value of our indexes lists
# and launch a loop again (sorry for that)
unique_molecule_sample = []
for i in range(len(unique_norms)):
  print('The {} type molecule, there is \n {}'.format(i+1, divided_molecules[unique_norms[i]]))
  unique_molecule_sample.append(divided_molecules[unique_norms[i]][0])

dim = len(unique_molecule_sample) #number of charts
fig, ax = plt.subplots(1, dim, figsize=(10, 5))
ax = ax.reshape(-1,)
for i in range(dim):
    j = unique_molecule_sample[i]
    draw_molecule(ax[i], molecules[j])
# Out:
# The 1 type molecule, there is
#  [0, 2, 3, 4, 5, 6, 7, 8, 9, 12, 14, 15, 16, 19, 21, 22, 24, 25, 27, 28, 30, 32, 33, 37, 38, 39, 40, 41, 42, 43, 45, 47, 48, 51, 53, 54, 55, 58, 59, 60, 61, 63, 64, 66, 67, 68, 69, 70, 71, 72, 74, 75, 76, 77, 78, 81, 83, 84, 85, 86, 89, 90, 91, 97, 98, 99, 100, 101, 103, 105, 108, 110, 111, 112, 115, 116, 118, 119, 122, 127, 129, 130, 131, 132, 133, 134, 135, 137, 138, 143, 144, 145, 147, 151, 152, 153, 154, 157, 158, 161, 163, 164, 165, 170, 171, 172, 174, 175, 178, 179, 180, 181, 182, 183, 184, 185, 187, 189, 190, 191, 193, 195, 196, 200, 202, 204, 206, 208, 211, 212, 213, 214, 215, 217, 218, 219, 221, 224, 226, 228, 229, 230, 232, 233, 234, 235, 236, 239, 242, 244, 246, 247, 249, 250, 251, 252, 255, 256, 258, 259, 260, 261, 263, 264, 266, 267, 268, 269, 270, 271, 272, 273, 275, 276, 277, 279, 280, 281, 284, 285, 286, 288, 291, 292, 293, 294, 295, 296, 300, 301, 303, 304, 305, 306, 307, 309, 313, 314, 315, 319, 322, 323, 324, 325, 326, 328, 329, 331, 333, 334, 339, 340, 347, 348, 351, 354, 356, 358, 359, 360, 361, 363, 364, 365, 366, 368, 369, 372, 373, 375, 377, 379, 380, 383, 384, 385, 386, 388, 390, 391, 394, 395, 396, 398, 399, 400, 401, 402, 404, 407, 409, 410, 411, 413, 414, 415, 416, 417, 418, 419, 421, 424, 426, 427, 429, 430, 431, 433, 434, 435, 440, 441, 443, 446, 447, 449, 451, 453, 455, 457, 458, 460, 462, 465, 467, 468, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 486, 488, 489, 490, 491, 493, 497, 499]
# The 2 type molecule, there is
#  [1, 10, 11, 13, 17, 18, 20, 23, 26, 29, 31, 34, 35, 36, 44, 46, 49, 50, 52, 56, 57, 62, 65, 73, 79, 80, 82, 87, 88, 92, 93, 94, 95, 96, 102, 104, 106, 107, 109, 113, 114, 117, 120, 121, 123, 124, 125, 126, 128, 136, 139, 140, 141, 142, 146, 148, 149, 150, 155, 156, 159, 160, 162, 166, 167, 168, 169, 173, 176, 177, 186, 188, 192, 194, 197, 198, 199, 201, 203, 205, 207, 209, 210, 216, 220, 222, 223, 225, 227, 231, 237, 238, 240, 241, 243, 245, 248, 253, 254, 257, 262, 265, 274, 278, 282, 283, 287, 289, 290, 297, 298, 299, 302, 308, 310, 311, 312, 316, 317, 318, 320, 321, 327, 330, 332, 335, 336, 337, 338, 341, 342, 343, 344, 345, 346, 349, 350, 352, 353, 355, 357, 362, 367, 370, 371, 374, 376, 378, 381, 382, 387, 389, 392, 393, 397, 403, 405, 406, 408, 412, 420, 422, 423, 425, 428, 432, 436, 437, 438, 439, 442, 444, 445, 448, 450, 452, 454, 456, 459, 461, 463, 464, 466, 469, 482, 483, 484, 485, 487, 492, 494, 495, 496, 498]

# %% [markdown]
# + (7 pts). Learn about [Kabsch algorithm](https://en.wikipedia.org/wiki/Kabsch_algorithm). Implement it and run on the database. Produce a list of distinct molecules and visualise them.

# %% [markdown]
# Kabsch algorithm is algorithm for the rotation of $P$ into $Q$ starts with two sets of paired points
# $$H = P^T Q$$
# Then we need
# 1. Find SVD decomposition to $H=U \Sigma V^T$ which is a cross-covariance matrix
# 2. Find $d = sign(\det(V U^T))$
# 3. For 2-dimenssional space find optimal rotation matrix
# $$ R = V
# \begin{pmatrix}
#   1 & 0\\
#   0& d
# \end{pmatrix}
# U^T$$

# %%
import numpy as np

def opt_rot_matrix(Q, P):
  H = P.T @ Q
  u, _, vh = np.linalg.svd(H, full_matrices=True)
  d = np.sign(np.linalg.det((u @ vh).T))
  matrix_d = np.array([[1, 0], [0, d]])
  R = vh.T @ matrix_d @ u.T
  return R

def rotated_matrix(Q,P):
  R = opt_rot_matrix(Q,P)
  return Q @ R

def matrix_comparing(A, B, n=2):
  return np.allclose(np.around(A, decimals=n), np.around(B,decimals=n))

# %%
rotated_matrix_res = []
for i in range(len(divided_molecules)):
  rotated_matrix_list = []
  a = molecules[divided_molecules[unique_norms[i]][0]]
  rotated_matrix_list.append(a)
  for j in range(1,len(divided_molecules[unique_norms[i]])):
    b = rotated_matrix(molecules[divided_molecules[unique_norms[i]][j]],a)
    if b not in rotated_matrix_list:
      rotated_matrix_list.append(b)
  rotated_matrix_res.append(np.array(rotated_matrix_list))


# I can't take np.unique for matrix
# But for this problem I need divide matrix for equillity by
# np.allclose
# and produce dictionary with 5 types of molecule

#(in my previous realisation I could do it, honestly)
# but my new way doesn't work T_T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-85ff6cffac01> in <module>
#       6   for j in range(1,len(divided_molecules[unique_norms[i]])):
#       7     b = rotated_matrix(molecules[divided_molecules[unique_norms[i]][j]],a)
# ----> 8     if b not in rotated_matrix_list:
#       9       rotated_matrix_list.append(b)
#      10   rotated_matrix_res.append(np.array(rotated_matrix_list))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
for i in range(500):
  for j in range(i,500):
    a = molecules[i]
    b = molecules[j]
    b_rot = rotated_matrix(b,a)
    if i!=j:
      if matrix_comparing(a,b_rot):
        print(i,':',j)

# %% [markdown]
# In my new approaches I have 5 molecule type
#
# When we compare our norm, we get 2 molecul type
#
# There is exist because norm-equllity doesn't mean matrix equallity
#
# We got matrix with negative elements
#
# and vector [0,1] and [-1,0] will have the same norm

# %% [markdown]
# # Problem 4 (Disentangled representation) (12 pts)

# %% [markdown]
# ## Brief intro

# %% [markdown]
# The main component of [GAN](https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html) is Generator network. Generator is such model that takes as input random vector and produces an image. In this task, we will work with the already pre-trained generator $G$. Here are a few things you need to know about this model:
#
#
#
# 1.   **Model input:** batch of random vectors $z\sim N(0,1)$ with normally distributed values of size **(Batch_Size,100)**. Here, Batch_Size is a number of images we want to generate
# 2.   **Model output:** $\mathrm{images} = G(z)$ - batch of images with size **(Batch_Size,3,64,64)**. Here **3** - defines number of image channels (3 for RGB images), **64, 64** - width and height.
# 3.   **Model structure:** generator is a set of sequentially appplied functions. Each function input is the output of the previous one. In other words, $G(z) = f_N(f_{N-1}...f_1(f_0(z)))$. $N$ - defines number of functions in generator.

# %% [markdown]
# ### Disentanglement

# %% [markdown]
# The good property of GAN is that generator input space has a set of meaningful directions - moving input vector along this directions produce interpretable changes in image. For example, we can change a Pose, Age, Expression or even add eyeglasses. You can read more about it on [resource](https://genforce.github.io/interfacegan/). The main question is how to find such good directions. This problem is called disentanglement.

# %% [markdown]
# ![](https://github.com/genforce/interfacegan/blob/master/docs/assets/teaser.jpg?raw=true)

# %% [markdown]
# ## Problem discription

# %% [markdown]
# We are going to find meaningful directions using SVD applied over the Jacobian matrix of some hidden output with respect to model input. **i-th** hidden output of generator model is defined by formula $G_{i}(z) = f_i(f_{i-1}...f_1(f_0(z))))$, where $i < N$. So, the task could be splitted on four main parts:
#
# 1. **(4 pts)**   Write the function **Get_Hidden_Output**, which reproduces formula $G_{i}(z) = f_i(f_{i-1}...f_1(f_0(z))))$
# 2. **(3 pts)**   Calculate jacobian matrix $J$ of generator $G$ for several **i** values. For each of them:
#
# *   Calculate the jacobian matrix with respect to $z$: $\frac{\partial G(z)}{\partial z}$
# *   Reshape jacobian matrix to have the size **(Batch_Size * Hidden_Output_Size,100)**
#
# 3. **(3 pts)**  Apply SVD to jacobian matrix ($J = U @ S @ V.T$) from previous step
#
# 4. **(2 pts)**  Take several directions from matrix $V$ (particular columns), and run visualization code (already written for you). Leave a comment on what you got (how found directions affect image)
#
# **Attention!!!**
#
# 1.  Please run the code on google colab to fulfil packages requirements
# 2.  Jacobian matrix computation may take more than 20 minutes!
# 3.  Use GPU runtime to accelerate computations

# %% [markdown]
# ## Prerequisites

# %%
# !pip install functorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting functorch
#   Downloading functorch-1.13.0-py2.py3-none-any.whl (2.1 kB)
# Collecting torch<1.13.1,>=1.13.0
#   Downloading torch-1.13.0-cp37-cp37m-manylinux1_x86_64.whl (890.2 MB)
#      |██████████████████████████████  | 834.1 MB 1.2 MB/s eta 0:00:48tcmalloc: large alloc 1147494400 bytes == 0x66470000 @  0x7fc49271e615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |████████████████████████████████| 890.2 MB 7.1 kB/s
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 32 kB/s
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 11 kB/s
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 62.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<1.13.1,>=1.13.0->functorch) (4.1.1)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 1.3 MB/s
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.13.1,>=1.13.0->functorch) (0.38.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.13.1,>=1.13.0->functorch) (57.4.0)
# Installing collected packages: nvidia-cublas-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, torch, functorch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.13.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.13.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.13.0 which is incompatible.
# Successfully installed functorch-1.13.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.0

# %%
import torch
from torch import nn
import requests
import matplotlib.pyplot as plt
import numpy as np
from torchvision import utils as vutils
from torchvision import transforms
from tqdm import tqdm
from google.colab import files
from functorch import vmap, jacfwd, jacrev
from functorch.experimental import replace_all_batch_norm_modules_
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /usr/local/lib/python3.7/dist-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
#   hidden generator size
ngf = 64

# Number of channels in the training images. For color images this is 3
nc = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

print(f"Device: {device}, latent size {nz}, generator hidden dim {ngf}, number of image channels {nc}")
# Out:
# Device: cuda:0, latent size 100, generator hidden dim 64, number of image channels 3

# %%
def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (nc) x 64 x 64
        )
    def get_function_output(self, inp, index=0):
      if index == 0:
        inp = inp[:,:,None,None]
      return self.main[index](inp)
    def get_number_of_layers(self):
      return len(self.main)

    def forward(self, input):
        return self.main(input[:,:,None,None])

# %%
file_id = "1hIh2-8KjcUku1Dl-mLYqEObbODrCW_Fp"
destination = './G_checkpoint.pt'
download_file_from_google_drive(file_id, destination)
G = Generator(1).to(device)
G.load_state_dict(torch.load('./G_checkpoint.pt', map_location="cpu"))
replace_all_batch_norm_modules_(G)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %%
def sample_batch(batch_size):
  return torch.randn((batch_size,nz),device=device)

# %%
def ToPILImage(tensor):
  return transforms.ToPILImage()(tensor)

# %%
def ConvertTensorsToOne(tensor, nrow=None):
  if nrow is None:
    nrow = int(tensor.size(0) ** 0.5)
  return vutils.make_grid(tensor, padding=2, normalize=True, nrow=nrow).cpu()

# %% [markdown]
# ## Generator network visualization

# %%
# generator model consist of 14 functions numbered from 0 to 13

G
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %%
# sample 64 random vectors to produce 64 images

z = sample_batch(64)

z.shape
# Out:
# torch.Size([64, 100])

# %%
# producing images

out = G(z)

out.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
# generate hidden output for given input (remember that functions are applied sequentially - input should be the output of previous function)
# index defines which function output will be returned
# for function with index 0 input will be model input "z"

hidden_output = G.get_function_output(z,index=0)

hidden_output.shape
# Out:
# torch.Size([64, 512, 4, 4])

# %%
# plotting the images by combining them into one, with 8 images in each row (nrow=8)

plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Generator output")
plt.imshow(ToPILImage(ConvertTensorsToOne(out, nrow=8)))

# %% [markdown]
# ## Perform experiments

# %% [markdown]
# **Define the function that returns the output of any generator function for
# given input z and generator function index (4 pts)**

# %%
def Get_Hidden_Output(z,index):
  output = z
  for i in range(index+1):
    output = G.get_function_output(output, index = i)
  out = output
  return out

# %% [markdown]
# **Define the function that calculates the jacobian matrix based on given input z and generator function index (use the function which you implemented earlier) (3 pts)**

# %%
def Calc_Gradient(z, index):
  h_o_size =1

  def func(z):
    return Get_Hidden_Output(z, index = index)
    
  grads = torch.autograd.functional.jacobian(func, z)
  hidden_output = Get_Hidden_Output(z, index)

  for i in range(len(hidden_output.shape)):
    h_o_size = hidden_output.shape[i] * h_o_size

  grads = grads.reshape(z.shape[0]*h_o_size, 100)
  return grads

# %%
index = 0
z = sample_batch(20)
grads = Calc_Gradient(z,index)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9f5ef2b43bb3> in <module>
#       1 index = 0
#       2 z = sample_batch(20)
# ----> 3 grads = Calc_Gradient(z,index)
#
# <ipython-input-15-54b7fae6c51c> in Calc_Gradient(z, index)
#       5     return Get_Hidden_Output(z, index = index)
#       6
# ----> 7   grads = torch.autograd.functional.jacobian(func, z)
#       8   hidden_output = Get_Hidden_Output(z, index)
#       9
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/functional.py in jacobian(func, inputs, create_graph, strict, vectorize, strategy)
#     672             for j in range(out.nelement()):
#     673                 vj = _autograd_grad((out.reshape(-1)[j],), inputs,
# --> 674                                     retain_graph=True, create_graph=create_graph)
#     675
#     676                 for el_idx, (jac_i_el, vj_el, inp_el) in enumerate(zip(jac_i, vj, inputs)):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/functional.py in _autograd_grad(outputs, inputs, grad_outputs, create_graph, retain_graph, is_grads_batched)
#     159         return torch.autograd.grad(new_outputs, inputs, new_grad_outputs, allow_unused=True,
#     160                                    create_graph=create_graph, retain_graph=retain_graph,
# --> 161                                    is_grads_batched=is_grads_batched)
#     162
#     163 def _fill_in_zeros(grads, refs, strict, create_graph, stage):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     300         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     301             t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
# --> 302             allow_unused, accumulate_grad=False)  # Calls into the C++ engine to run the backward pass
#     303
#     304
#
# KeyboardInterrupt:

# %%
grads.shape
# Out:
# torch.Size([3276800, 100])

# %% [markdown]
# **Calculate SVD and visualize singular values for several generator function indexes (2-3 indexes are enough). Based on singular value plots, decide what generator function is more useful for disentangled representation search and why, leave a comment.(3 pts)**

# %%
U, S, V = torch.svd(grads)

# %%
def S_calc(z, index):
  grads = Calc_Gradient(z,index)
  _,S,V = torch.svd(grads)
  S_np = S.cpu().numpy()
  return S_np, V

S_arr = []
V_arr = []
lst = [0,1,2]
for i in lst:
  S_i, V_i = S_calc(z, i)
  S_arr.append(S_i)
  V_arr.append(V_i)

# %%
lab = ['index 0','index 1', 'index 2']
plt.plot(np.linspace(0,100,100),S_arr[0], label = lab[0])
plt.plot(np.linspace(0,100,100),S_arr[1], label = lab[1])
plt.plot(np.linspace(0,100,100),S_arr[2], label = lab[2])
# plt.plot(np.linspace(0,100,100),S_3, label = 'index 3')
plt.xlabel('fraction')
plt.ylabel('Singular-value')
plt.legend();

# %% [markdown]
# **Choose some directions from matrix V (some columns) corresponding to chosen generator function index (based on previous step). Run visualization code. Which image attributes affects chosen directions? (2 pts)**

# %%
def make_edit(input, dirs):
  output = G(input)
  input_shift = input[:,None,:] + dirs[None,:,:]*3
  output_shift = G(input_shift.reshape(-1,nz)).reshape(input.size(0),-1,3,64,64)
  return torch.cat([output[:,None],output_shift],dim=1).reshape(-1,3,64,64)

# %%
input = sample_batch(4)
dirs = V_arr[2][0:9]

# %%
out = make_edit(input, dirs)
plt.figure(figsize=(16,16))
plt.axis("off")
plt.imshow(ToPILImage(ConvertTensorsToOne(out, nrow=(dirs.size(0)+1))))
